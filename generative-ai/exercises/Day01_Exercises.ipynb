# %% [markdown]
# <div align="center">
# <img src="https://poorit.in/image.png" alt="Poorit" width="40" style="vertical-align: middle;"> <b>LPU — GENERATIVE AI</b>
#
# ## Day 1 — Exercises
#
# **Lovely Professional University**  ·  Poorit Technologies
#
# </div>
#
# ---
#
# Each exercise gives you the **steps** — you write the code yourself. Run a cell with **Shift + Enter**.

# %% [markdown]
# ## Exercise 1 — Two-provider tagline race (LiteLLM)
#
# Send the **same** tagline prompt to two providers and compare their answers.

# %%
# Exercise 1 — Two-provider tagline race (LiteLLM)
# Goal: send the SAME tagline prompt to two providers and compare.

# 1. install litellm            ->  !pip install -q litellm
# 2. import completion from litellm
# 3. getpass your OpenAI key and your Gemini key
# 4. set them as env vars       ->  OPENAI_API_KEY, GEMINI_API_KEY
# 5. build a system message (creative branding expert)
#    and a user message (a one-line tagline for a company you pick)
# 6. call completion() for OpenAI  ->  model = "openai/gpt-4o-mini"      (add a temperature)
# 7. call completion() for Gemini  ->  model = "gemini/gemini-2.0-flash" (add a temperature)
# 8. print both answers to compare


# your code here
